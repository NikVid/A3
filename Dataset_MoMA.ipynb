# %%
import pandas as pd

# %%
pd.options.display.max_rows = 100

# %%
bellevue_df = pd.read_csv("TheNewest_MoMAExhibitions1929to1989_12.csv", delimiter=";", low_memory=False)
new_df = bellevue_df[['ExhibitionID','ExhibitionTitle','ExhibitionCitationDate','ExhibitionBeginDate','ExhibitionEndDate','ExhibitionSortOrder','ExhibitionURL','ExhibitionRole','ExhibitionRoleinPressRelease','DisplayName','FirstName','MiddleName','LastName','Suffix','Nationality','ConstituentBeginDate','ConstituentEndDate','ArtistBio','Gender','ConstituentURL']]
new_df
# Out:
#        ExhibitionID                              ExhibitionTitle  \
# 0            2557.0              Cézanne Gauguin Seurat Van Gogh
# 1            2557.0              Cézanne Gauguin Seurat Van Gogh
# 2            2557.0            Cézanne, Gauguin, Seurat Van Gogh
# 3            2557.0              Cézanne Gauguin Seurat Van Gogh
# 4            2557.0              Cézanne Gauguin Seurat Van Gogh
# ...             ...                                          ...
# 34549         288.0  Recent Japanese Posters from the Collection
# 34550         288.0  Recent Japanese Posters from the Collection
# 34551         288.0  Recent Japanese Posters from the Collection
# 34552         288.0  Recent Japanese Posters from the Collection
# 34553        3367.0                Directed by Vincente Minnelli
#
#                                   ExhibitionCitationDate ExhibitionBeginDate  \
# 0            [MoMA Exh. #1, November 7-December 7, 1929]           7-11-1929
# ...

# %%
new_df
# Out:
#        ExhibitionID                              ExhibitionTitle  \
# 0            2557.0              Cézanne Gauguin Seurat Van Gogh
# 1            2557.0              Cézanne Gauguin Seurat Van Gogh
# 2            2557.0            Cézanne, Gauguin, Seurat Van Gogh
# 3            2557.0              Cézanne Gauguin Seurat Van Gogh
# 4            2557.0              Cézanne Gauguin Seurat Van Gogh
# ...             ...                                          ...
# 34549         288.0  Recent Japanese Posters from the Collection
# 34550         288.0  Recent Japanese Posters from the Collection
# 34551         288.0  Recent Japanese Posters from the Collection
# 34552         288.0  Recent Japanese Posters from the Collection
# 34553        3367.0                Directed by Vincente Minnelli
#
#                                   ExhibitionCitationDate ExhibitionBeginDate  \
# 0            [MoMA Exh. #1, November 7-December 7, 1929]           7-11-1929
# ...

# %%
##Display first few rows
new_df.head(80)
# Out:
#     ExhibitionID                                  ExhibitionTitle  \
# 0         2557.0                  Cézanne Gauguin Seurat Van Gogh
# 1         2557.0                  Cézanne Gauguin Seurat Van Gogh
# 2         2557.0                Cézanne, Gauguin, Seurat Van Gogh
# 3         2557.0                  Cézanne Gauguin Seurat Van Gogh
# 4         2557.0                  Cézanne Gauguin Seurat Van Gogh
# 5         2724.0                 Paintings by 19 Living Americans
# 6         2724.0                 Paintings by 19 Living Americans
# 7         2724.0                 Paintings by 19 Living Americans
# 8         2724.0                 Paintings by 19 Living Americans
# 9         2724.0                 Paintings by 19 Living Americans
# 10        2724.0                 Paintings by 19 Living Americans
# 11        2724.0                 Paintings by 19 Living Americans
# 12        2724.0                 Paintings by 19 Living Americans
# ...

# %%
##get info
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34554 entries, 0 to 34553
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ExhibitionID                  34125 non-null  float64
#  1   ExhibitionTitle               34329 non-null  object
#  2   ExhibitionCitationDate        34224 non-null  object
#  3   ExhibitionBeginDate           33656 non-null  object
#  4   ExhibitionEndDate             32458 non-null  object
#  5   ExhibitionSortOrder           33656 non-null  object
#  6   ExhibitionURL                 33234 non-null  object
#  7   ExhibitionRole                33531 non-null  object
#  8   ExhibitionRoleinPressRelease  33531 non-null  object
#  9   DisplayName                   33531 non-null  object
#  10  FirstName                     30630 non-null  object
#  11  MiddleName                    3706 non-null   object
# ...

# %%
##calculate summary statisti: everything that is a float will be calculated
new_df.describe()
# Out:
#        ExhibitionID  ConstituentBeginDate  ConstituentEndDate
# count  34125.000000          24442.000000        19024.000000
# mean    2940.600381           1899.784838         1964.423045
# std     1799.761847             35.306761           39.538360
# min        2.000000           1390.000000          186.000000
# 25%     2600.000000           1883.000000         1949.000000
# 50%     2983.000000           1901.000000         1969.000000
# 75%     3908.000000           1924.000000         1987.000000
# max    11268.000000           1998.000000         2015.000000

# %%
## to include all in the calculation use this:
new_df.describe(include='all')

##From this I can deduce: 
##The  artists whose works are exhibited in MoMA are mostly American(from 'ArtstBio') and male (from 'gender'). 
##Artist whose works are most present at the exhibitions at MoMA is Pablo Picasso
# Out:
#         ExhibitionID ExhibitionTitle  \
# count   34125.000000           34329
# unique           NaN            1653
# top              NaN     Good Design
# freq             NaN             768
# mean     2940.600381             NaN
# std      1799.761847             NaN
# min         2.000000             NaN
# 25%      2600.000000             NaN
# 50%      2983.000000             NaN
# 75%      3908.000000             NaN
# max     11268.000000             NaN
#
#                                ExhibitionCitationDate ExhibitionBeginDate  \
# count                                           34224               33656
# unique                                           1767                1498
# top     [MoMA Exh. #1250, February 21-April 24, 1979]           24-5-1944
# freq                                              321                 559
# mean                                              NaN                 NaN
# ...

# %%
## to count the unique values
## from here I can deduce that MoMA has hosted mostly male artists (22.454 + 1("male")), while there is only 2461 women that have exbited between the years 1929-1989.
new_df['Gender'].value_counts()
# Out:
# Male      22454
# Female     2461
# male          1
# Name: Gender, dtype: int64

# %%
##from here I can deduce 5 most frequent natioalities of the artists that have exhibited in MoMA, with American being the most frequent nationality
new_df['Nationality'].value_counts()[:5]
# Out:
# American    13679
# French       3624
# German       1665
# British      1120
# Italian       821
# Name: Nationality, dtype: int64

# %%
##in order to plot, use this:
new_df['Gender'].value_counts()[:2].plot(kind='bar', title='Museum of Modern Art:\nGender Frequency')
# Out:
# <AxesSubplot:title={'center':'Museum of Modern Art:\nGender Frequency'}>

# %%
bellevue_df['Nationality'].value_counts()[:10].plot(kind='pie', title='Museum of Modern Art:\nNationality Frequency')
# Out:
# <AxesSubplot:title={'center':'Museum of Modern Art:\nNationality Frequency'}, ylabel='Nationality'>

# %%
##FILTERING: select rows that only contain the certain value:

new_df[new_df['Gender'] == 'Female']
# Out:
#        ExhibitionID                                    ExhibitionTitle  \
# 18           2724.0                   Paintings by 19 Living Americans
# 37           2942.0                                  Painting in Paris
# 56           2944.0    46 Painters and Sculptors under 35 Years of Age
# 93           2944.0    46 Painters and Sculptors under 35 Years of Age
# 133          2725.0          Summer Exhibition: Painting and Sculpture
# ...             ...                                                ...
# 34461        2906.0  Drawings of the Eighties from the Collection, ...
# 34465        2906.0  Drawings of the Eighties from the Collection, ...
# 34469        2906.0  Drawings of the Eighties from the Collection, ...
# 34474        2906.0  Drawings of the Eighties from the Collection, ...
# 34487         737.0                  For 20 Years: Editions Schellmann
#
#                                   ExhibitionCitationDate ExhibitionBeginDate  \
# ...

# %%
new_df['Gender'] == 'Female'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 34549    False
# 34550    False
# 34551    False
# 34552    False
# 34553    False
# Name: Gender, Length: 34554, dtype: bool

# %%
##create a new name(variable) for the filtered data:
women_filter = new_df['Gender'] == 'Female'

# %%
MoMA_women = new_df[women_filter]

# %%
MoMA_women['Nationality'].value_counts()
# Out:
# American                1735
# French                    97
# German                    89
# British                   81
# Russian                   63
# Swiss                     38
# Japanese                  29
# Italian                   27
# Venezuelan                27
# Canadian                  19
# Brazilian                 16
# Polish                    13
# Argentine                 10
# Cuban                     10
# Mexican                    9
# Swedish                    9
# Finnish                    8
# Austrian                   8
# Hungarian                  7
# Yugoslav                   7
# Nationality unknown        7
# Icelandic                  6
# Czech                      6
# Dutch                      6
# Peruvian                   3
# Belgian                    2
# Spanish                    2
# Australian                 2
# Chilean                    2
# Colombian                  2
# Croatian                   2
# Israeli                    2
# ...

# %%
MoMA_women['ExhibitionBeginDate'].value_counts()
# Out:
# 17-5-1984     46
# 27-5-1964     40
# 26-11-1958    25
# 24-5-1944     25
# 31-1-1988     24
#               ..
# 23-9-1977      1
# 18-9-1981      1
# 10-3-1943      1
# 30-5-1961      1
# 26-8-1974      1
# Name: ExhibitionBeginDate, Length: 682, dtype: int64

# %%
MoMA_women['Nationality'].value_counts().plot(kind='bar', figsize=(10,10), title='MoMA:\nNationality Frequency')
# Out:
# <AxesSubplot:title={'center':'MoMA:\nNationality Frequency'}>

# %%
##transform it to CSV
MoMA_women.to_csv("MoMA_Women.csv", encoding='utf-8', index=False)

# %% [markdown]
# ### Part Two

# %%
##there are 2461 rows and 61 collumns
MoMA_women.shape
# Out:
# (2461, 20)

# %%
MoMA_women.columns
# Out:
# Index(['ExhibitionID', 'ExhibitionTitle', 'ExhibitionCitationDate',
#        'ExhibitionBeginDate', 'ExhibitionEndDate', 'ExhibitionSortOrder',
#        'ExhibitionURL', 'ExhibitionRole', 'ExhibitionRoleinPressRelease',
#        'DisplayName', 'FirstName', 'MiddleName', 'LastName', 'Suffix',
#        'Nationality', 'ConstituentBeginDate', 'ConstituentEndDate',
#        'ArtistBio', 'Gender', 'ConstituentURL'],
#       dtype='object')

# %%
#Missing data:
#how many women artists in the database are still alive or whose date of death isn'r recorded/known?

MoMA_women['ConstituentEndDate'].notna()
# Out:
# 18        True
# 37        True
# 56        True
# 93        True
# 133       True
#          ...
# 34461    False
# 34465    False
# 34469    False
# 34474    False
# 34487     True
# Name: ConstituentEndDate, Length: 2461, dtype: bool

# %%
MoMA_women[MoMA_women['ConstituentEndDate'].notna()]
# Out:
#        ExhibitionID                                  ExhibitionTitle  \
# 18           2724.0                 Paintings by 19 Living Americans
# 37           2942.0                                Painting in Paris
# 56           2944.0  46 Painters and Sculptors under 35 Years of Age
# 93           2944.0  46 Painters and Sculptors under 35 Years of Age
# 133          2725.0        Summer Exhibition: Painting and Sculpture
# ...             ...                                              ...
# 34308        2907.0                         Painters for the Theater
# 34326        2907.0                         Painters for the Theater
# 34337        2907.0                         Painters for the Theater
# 34362         368.0                               The Cubist Imprint
# 34487         737.0                For 20 Years: Editions Schellmann
#
#                                   ExhibitionCitationDate ExhibitionBeginDate  \
# ...

# %%
MoMA_women['ConstituentEndDate'].isna().value_counts()
# Out:
# False    1433
# True     1028
# Name: ConstituentEndDate, dtype: int64

# %%
#percentage:
#about 41% of rows have the information of the death date in this dataset and about 58% does not 
#date of death is not known/recorded or the artist is still alive.

MoMA_women['ConstituentEndDate'].isna().value_counts(normalize=True)
# Out:
# False    0.582284
# True     0.417716
# Name: ConstituentEndDate, dtype: float64

# %%
#in order to see how much data is there/missing in the individual collumns:
MoMA_women.count() / len(MoMA_women)
# Out:
# ExhibitionID                    0.982121
# ExhibitionTitle                 1.000000
# ExhibitionCitationDate          1.000000
# ExhibitionBeginDate             1.000000
# ExhibitionEndDate               0.958553
# ExhibitionSortOrder             1.000000
# ExhibitionURL                   0.982121
# ExhibitionRole                  1.000000
# ExhibitionRoleinPressRelease    1.000000
# DisplayName                     1.000000
# FirstName                       0.982527
# MiddleName                      0.096709
# LastName                        1.000000
# Suffix                          0.000000
# Nationality                     0.953271
# ConstituentBeginDate            0.900447
# ConstituentEndDate              0.582284
# ArtistBio                       0.953271
# Gender                          1.000000
# ConstituentURL                  1.000000
# dtype: float64

# %%
##rename the values

MoMA_women['ConstituentEndDate'].fillna('date of birth unknown/not recorded')
# Out:
# 18                                   1986.0
# 37                                   1956.0
# 56                                   1987.0
# 93                                   1975.0
# 133                                  1956.0
#                         ...
# 34461    date of birth unknown/not recorded
# 34465    date of birth unknown/not recorded
# 34469    date of birth unknown/not recorded
# 34474    date of birth unknown/not recorded
# 34487                                2009.0
# Name: ConstituentEndDate, Length: 2461, dtype: object

# %%
##rename collumn:
MoMA_women.rename(columns={'ConstituentEndDate': 'YearOfDeath'})
# Out:
#        ExhibitionID                                    ExhibitionTitle  \
# 18           2724.0                   Paintings by 19 Living Americans
# 37           2942.0                                  Painting in Paris
# 56           2944.0    46 Painters and Sculptors under 35 Years of Age
# 93           2944.0    46 Painters and Sculptors under 35 Years of Age
# 133          2725.0          Summer Exhibition: Painting and Sculpture
# ...             ...                                                ...
# 34461        2906.0  Drawings of the Eighties from the Collection, ...
# 34465        2906.0  Drawings of the Eighties from the Collection, ...
# 34469        2906.0  Drawings of the Eighties from the Collection, ...
# 34474        2906.0  Drawings of the Eighties from the Collection, ...
# 34487         737.0                  For 20 Years: Editions Schellmann
#
#                                   ExhibitionCitationDate ExhibitionBeginDate  \
# ...

# %%
MoMA_women = MoMA_women.rename(columns={'ConstituentEndDate': 'YearOfDeath', 'ConstituentBeginDate': 'YearOfBirth'})

# %%
MoMA_women.head(1)
# Out:
#     ExhibitionID                   ExhibitionTitle  \
# 18        2724.0  Paintings by 19 Living Americans
#
#                           ExhibitionCitationDate ExhibitionBeginDate  \
# 18  [MoMA Exh. #2, December 12-January 12, 1930]          12-12-1929
#
#    ExhibitionEndDate ExhibitionSortOrder                       ExhibitionURL  \
# 18         12-1-1930                   2  moma.org/calendar/exhibitions/1912
#
#    ExhibitionRole ExhibitionRoleinPressRelease       DisplayName FirstName  \
# 18         Artist                       Artist  Georgia O'Keeffe   Georgia
#
#    MiddleName  LastName Suffix Nationality  YearOfBirth  YearOfDeath  \
# 18        NaN  O'Keeffe    NaN    American       1887.0       1986.0
#
#               ArtistBio  Gender         ConstituentURL
# 18  American, 1887–1986  Female  moma.org/artists/4360

# %%
##drop collumn:
MoMA_women = MoMA_women.drop(columns="ExhibitionCitationDate")

# %%
MoMA_women.columns
# Out:
# Index(['ExhibitionID', 'ExhibitionTitle', 'ExhibitionBeginDate',
#        'ExhibitionEndDate', 'ExhibitionSortOrder', 'ExhibitionURL',
#        'ExhibitionRole', 'ExhibitionRoleinPressRelease', 'DisplayName',
#        'FirstName', 'MiddleName', 'LastName', 'Suffix', 'Nationality',
#        'YearOfBirth', 'YearOfDeath', 'ArtistBio', 'Gender', 'ConstituentURL'],
#       dtype='object')

# %%
##sorting dataa;

MoMA_women.sort_values(by='ExhibitionSortOrder', ascending=True)
# Out:
#        ExhibitionID                                    ExhibitionTitle  \
# 177          2729.0         Painting and Sculpture by Living Americans
# 22621        2758.0  The New American Painting and Sculpture: The F...
# 22648        2758.0  The New American Painting and Sculpture: The F...
# 22635        2758.0  The New American Painting and Sculpture: The F...
# 22669           NaN              Family: Portraits from the Collection
# ...             ...                                                ...
# 22517        2873.0  Twentieth-Century Art from the Nelson Aldrich ...
# 22585        2873.0  Twentieth-Century Art from the Nelson Aldrich ...
# 22497        2873.0  Twentieth-Century Art from the Nelson Aldrich ...
# 22510        2873.0  Twentieth-Century Art from the Nelson Aldrich ...
# 22548        2873.0  Twentieth-Century Art from the Nelson Aldrich ...
#
#       ExhibitionBeginDate ExhibitionEndDate ExhibitionSortOrder  \
# ...

# %%
##Group by
MoMA_women.groupby('Nationality')

# %%
#count in this group:
MoMA_women.groupby('Nationality').count()
# Out:
#                       ExhibitionID  ExhibitionTitle  ExhibitionBeginDate  \
# Nationality
# American                      1699             1735                 1735
# American and Mexican             1                1                    1
# Argentine                       10               10                   10
# Australian                       2                2                    2
# Austrian                         8                8                    8
# Belgian                          2                2                    2
# Brazilian                       16               16                   16
# British                         80               81                   81
# Canadian                        19               19                   19
# Chilean                          2                2                    2
# Colombian                        2                2                    2
# Croatian                         2                2                    2
# ...

# %%
##isolate the "Gender" colum
MoMA_women.groupby('Nationality').count()['Gender']
# Out:
# Nationality
# American                1735
# American and Mexican       1
# Argentine                 10
# Australian                 2
# Austrian                   8
# Belgian                    2
# Brazilian                 16
# British                   81
# Canadian                  19
# Chilean                    2
# Colombian                  2
# Croatian                   2
# Cuban                     10
# Czech                      6
# Dutch                      6
# Finnish                    8
# French                    97
# German                    89
# Hungarian                  7
# Icelandic                  6
# Israeli                    2
# Italian                   27
# Japanese                  29
# Mexican                    9
# Nationality unknown        7
# Peruvian                   3
# Polish                    13
# Russian                   63
# Scottish                   1
# Spanish                    2
# Swedish                    9
# ...

# %%
MoMA_women.groupby('Nationality')['Gender'].count().sort_values(ascending=False)
##from here I can deduce that the female artists exhibiting their artworks were majorly American, followed by the French and German artists.
# Out:
# Nationality
# American                1735
# French                    97
# German                    89
# British                   81
# Russian                   63
# Swiss                     38
# Japanese                  29
# Venezuelan                27
# Italian                   27
# Canadian                  19
# Brazilian                 16
# Polish                    13
# Cuban                     10
# Argentine                 10
# Swedish                    9
# Mexican                    9
# Finnish                    8
# Austrian                   8
# Nationality unknown        7
# Hungarian                  7
# Yugoslav                   7
# Icelandic                  6
# Dutch                      6
# Czech                      6
# Peruvian                   3
# Israeli                    2
# Croatian                   2
# Spanish                    2
# Colombian                  2
# Chilean                    2
# Belgian                    2
# ...

# %%
MoMA_women["ExhibitionBeginDate"] = MoMA_women["ExhibitionBeginDate"].apply(lambda x: dateutil.parser.parse(x))
year = MoMA_women["ExhibitionBeginDate"].dt.to_period("Y")
agg = MoMA_women.groupby([year])
for group in agg:
    print(group)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-170-2f4ea31fbd4b> in <module>
# ----> 1 MoMA_women["ExhibitionBeginDate"] = MoMA_women["ExhibitionBeginDate"].apply(lambda x: dateutil.parser.parse(x))
#       2 year = MoMA_women["ExhibitionBeginDate"].dt.to_period("Y")
#       3 agg = MoMA_women.groupby([year])
#       4 for group in agg:
#       5     print(group)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-170-2f4ea31fbd4b> in <lambda>(x)
# ...

# %%
MoMA_women.groupby('Nationality')['Gender'].count()\
.sort_values(ascending=False).plot(kind='bar', title='Which nationality is most common among women exhibiting their artworks at MoMA?')
# Out:
# <AxesSubplot:title={'center':'Which nationality is most common among women exhibiting their artworks at MoMA?'}, xlabel='Nationality'>

# %%
##Time series:
MoMA_women['ExhibitionBeginDate'].dtype
# Out:
# dtype('O')
